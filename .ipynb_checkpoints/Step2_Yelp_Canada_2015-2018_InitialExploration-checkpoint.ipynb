# %% [markdown]
# # Initial Exploration and Analysis of 2015-2018 Restaurant Reviews Data in Canada

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("ggplot")
# import sys
# reload(sys)
# sys.setdefaultencoding('utf-8')

# %%
df = pd.read_csv('2016-2017_canada_restaurant_reviews.csv')

# %%
df.head()
# Out:
#               business_id              name            categories  avg_stars  \
# 0  --1UhMGODdWsrMastO9DZw  The Spicy Amigos  Restaurants, Mexican        4.0
# 1  --1UhMGODdWsrMastO9DZw  The Spicy Amigos  Restaurants, Mexican        4.0
# 2  --1UhMGODdWsrMastO9DZw  The Spicy Amigos  Restaurants, Mexican        4.0
# 3  --1UhMGODdWsrMastO9DZw  The Spicy Amigos  Restaurants, Mexican        4.0
# 4  --1UhMGODdWsrMastO9DZw  The Spicy Amigos  Restaurants, Mexican        4.0
#
#    cool        date  funny               review_id  stars  \
# 0     0  2016-07-25      0  0tFxHz2j1GJ8-IYPp5NxWA      4
# 1     1  2016-12-06      0  KByp3bKAt9GMqU7koJ8htg      5
# 2     0  2017-12-12      0  e1HiHHD7CzY5NKZG7hvhTw      5
# 3     0  2017-08-09      0  oKm8UTv-QSC0oCbniqwxjg      4
# 4     1  2016-07-16      0  -i9u19L08A4VvhFVfqXK9Q      5
#
#                                                 text  useful  \
# 0  came lunch last week pleasant surpri fresh tas...       0
# 1  want mexican reason price citi gotta quesadill...       0
# 2  absolut delici great servic well glad forgot l...       0
# 3  tasti authent mexican street food give appropr...       0
# 4  first time sinc chang ownership burrito beer l...       0
#
#                   user_id
# 0  t4cYW73lVcBb-1R_Wms1RQ
# 1  hqk4eugYhjmhM-3S2FwGjA
# 2  Sew1Nht6Q0sGTIZeNvRfLw
# 3  NoQCmYKyMPs4D01Wa6dZew
# 4  qUnvyCfCpr9ZG_F5oezJMw

# %% [markdown]
# ### 1. What are the top 50 restaurants with most reviews in Canada between 2016-2017 ?

# %%
business_id = list(df.groupby(['business_id'])['review_id'].count().index)
resturant_name = [pd.unique(df[df['business_id'] == res]['name'])[0] for res in business_id]
popularity = list(df.groupby(['business_id'])['review_id'].count())
plt.figure(figsize=(10,10))
objects = [resturant_name[i] for i in np.argsort(popularity)[::-1][:50]] # 存储前50名饭店名，argsort返回从小到大的索引
y_pos = np.arange(len(objects)) # tick的位置
plt.barh(y_pos, np.sort(popularity)[::-1][:50], align='center', alpha = 0.4) # 位置，柱宽度。。。
plt.yticks(y_pos, objects) # 位置loc，标记label
plt.xlabel('Number of reviews')
plt.title('Top 50 resturants with most reviews in Canada between 2016-2017')
plt.gca().invert_yaxis() # gca(**kwargs)获得当前符合参数条件的axes的实例，invert_yaxis反转y轴

# %% [markdown]
# ### 2. Whether the more reviews means the better quality ?

# %%
avg_starts = df.groupby(['business_id'])['avg_stars'].mean()
plt.figure(figsize=(10,10))
objects = [resturant_name[i] for i in np.argsort(popularity)[::-1][:50]]
y_pos = np.arange(len(objects))
plt.barh(y_pos, [avg_starts[i] for i in np.argsort(popularity)[::-1][:50]], align='center', alpha = 0.5)
plt.yticks(y_pos, objects)
plt.xlabel('Average stars')
plt.title('Average rating for top 50 resturants with most reviews')
plt.gca().invert_yaxis()

# %%
print('The average rate for all resturants in Canada is %f.' \
     %(np.mean(avg_starts)))
print('The proportion of top 50 resturants with rate less than 4 is %f.' \
     %(sum(np.array([avg_starts[i] for i in np.argsort(popularity)[::-1][:50]]) < 4.0)/50.0))
print('The proportion of top 50 resturants with rate less than 3.5 is %f.' \
     %(sum(np.array([avg_starts[i] for i in np.argsort(popularity)[::-1][:50]]) < 3.5)/50.0))
# Out:
# The average rate for all resturants in Canada is 3.493441.
# The proportion of top 50 resturants with rate less than 4 is 0.220000.
# The proportion of top 50 resturants with rate less than 3.5 is 0.040000.

# %% [markdown]
# **Check how strong the number of reviews and the average rating are related?**

# %%
# Pearson product-moment correlation coefficient皮尔逊积矩相关系数,(-1,1),度量变量之间的线性相关程度
from scipy.stats.stats import pearsonr 
print('The correlation coefficient between number of reviews and average rating is %f.' \
      % (pearsonr(np.array(popularity), avg_starts)[0]))
# Out:
# The correlation coefficient between number of reviews and average rating is 0.136760.

# %% [markdown]
# **Conclusion: 0.13676 is quite close to 0, which means the relationship between number of reviews and average rating is poor**
#
# **说明“评论数量”与“平均得分”之间的相关性很弱**

# %% [markdown]
# ### 3. What are the popular restaurant styles in Canada between 2015 and 2018 ?

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer()
corpus = df['categories']
X = vectorizer.fit_transform(corpus) 
X = np.sum(X, axis=0)
X = np.array(X)[0]
cate_label = vectorizer.get_feature_names()

# %% [markdown]
# **Pick out top 30 labels**

# %%
top_30_label = [cate_label[i] for i in np.argsort(X)[::-1][1:31]]
top_30_percentage = [X[i]/sum(X) for i in np.argsort(X)[::-1][1:31]]
print('%48s %25s' % ('Label name', 'Percentage of all labels'))
for i in range(30):
    print('%24s %24s %24f' % \
          (str(i+1), top_30_label[i], top_30_percentage[i]))
# Out:
#                                       Label name  Percentage of all labels
#                        1                     food                 0.072089
#                        2                     bars                 0.062844
#                        3                nightlife                 0.031922
#                        4                      new                 0.025480
#                        5                 american                 0.022064
#                        6                breakfast                 0.020926
#                        7                   brunch                 0.020919
#                        8                 japanese                 0.019639
#                        9                 canadian                 0.018181
#                       10                  chinese                 0.017409
#                       11               sandwiches                 0.013225
#                       12                      tea                 0.013136
#                       13                    cafes                 0.013055
#                       14              traditional                 0.012955
#                       15                  italian                 0.012507
#                       16                   coffee                 0.011570
#                       17                    asian                 0.011471
#                       18                    pizza                 0.011154
#                       19                    sushi                 0.011140
#                       20                   fusion                 0.011093
#                       21                  burgers                 0.010874
#                       22                  seafood                 0.010379
#                       23                  mexican                 0.008900
#                       24                 desserts                 0.008876
#                       25                     wine                 0.007942
#                       26                   french                 0.007571
#                       27                specialty                 0.007418
#                       28                    tapas                 0.007317
#                       29                     fast                 0.007010
#                       30                     pubs                 0.006951
