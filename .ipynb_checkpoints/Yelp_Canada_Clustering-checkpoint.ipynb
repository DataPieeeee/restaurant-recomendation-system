# %% [markdown]
# # Yelp Data Challenge - Clustering Analysis
# Summary:
# - From Setiment analysis, I come to the conclusion that rating score is unreasonable in 4-5 stars cases and 1-2 stars cases. I suggest to replace 1-5 rating system with like/dislike or below_average/average/above_average systems. Here I want to determine which one is better through clustering analysis.
# - The clutsering method is K-means. It turns out that three clusters (below_average/average/above_average) has better performance than two clusters (like/dislike).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use("ggplot")

# %%
df = pd.read_csv('2017_restaurant_reviews.csv')
df.head(2)
# Out:
#               business_id              name            categories  avg_stars  \
# 2  --1UhMGODdWsrMastO9DZw  The Spicy Amigos  Restaurants, Mexican        4.0
# 3  --1UhMGODdWsrMastO9DZw  The Spicy Amigos  Restaurants, Mexican        4.0
#
#    cool        date  funny               review_id  stars  \
# 2     0  2017-12-12      0  e1HiHHD7CzY5NKZG7hvhTw      5
# 3     0  2017-08-09      0  oKm8UTv-QSC0oCbniqwxjg      4
#
#                                                 text  useful  \
# 2  Absolutely delicious! And great service as wel...       0
# 3  Tasty, authentic Mexican street food that give...       0
#
#                   user_id
# 2  Sew1Nht6Q0sGTIZeNvRfLw
# 3  NoQCmYKyMPs4D01Wa6dZew

# %% [markdown]
# # Cluster the review text data for all the restaurants

# %% [markdown]
# #### 1. Define my feature variables - the text of the review

# %%
documents = df['text']
print(len(documents))
# Out:
# 198993

# %% [markdown]
# #### 2. Create training dataset and test dataset

# %%
from sklearn.model_selection import train_test_split
# The clsutering algorithms is slow so I will take samples to find optima number of clusters
documents_train, documents_test= train_test_split(documents, test_size=0.3)

# %% [markdown]
# #### 3. Get NLP representation of the documents

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# Create TfidfVectorizer
vectorizer = TfidfVectorizer(analyzer = 'word', stop_words = 'english', 
                             lowercase = True, max_features = 5000
                            )
# Train the model with my training data
documents_train_vec = vectorizer.fit_transform(documents_train).toarray()#[:300]
# Get the vocab of my tfidf
words = vectorizer.get_feature_names()
# Use the trained model to transform all the reviews
documents_vec = vectorizer.transform(documents).toarray()#[:300]  #documents=df['text']

# %% [markdown]
# #### 4. Cluster reviews with KMeans (two clusters)

# %% [markdown]
# Fit k-means clustering with the training vectors and apply it on all the data

# %%
from sklearn.cluster import KMeans
km_clf = KMeans(verbose = 0,n_clusters = 2)

# %%
km_clf.fit(documents_train_vec) #memory error

# %% [markdown]
# #### 5. Make predictions on all your data

# %%
cluster = km_clf.predict(documents_vec)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-30-a7787a7ca303> in <module>()
# ----> 1 cluster = km_clf.predict(documents_vec)
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py in predict(self, X)
#     984             Index of the cluster each sample belongs to.
#     985         """
# --> 986         check_is_fitted(self, 'cluster_centers_')
#     987
#     988         X = self._check_test_data(X)
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#     766
#     767     if not all_or_any([hasattr(estimator, attr) for attr in attributes]):
# --> 768         raise NotFittedError(msg % {'name': type(estimator).__name__})
#     769
#     770
#
# NotFittedError: This KMeans instance is not fitted yet. Call 'fit' with appropriate arguments before using this method.

# %% [markdown]
# #### 6. Inspect the centroids
# To find out what "topics" Kmeans has discovered I must inspect the centroids. Print out the centroids of the Kmeans clustering.
# These centroids are simply a bunch of vectors.  To make any sense of them I need to map these vectors back into 'word space'.  Think of each feature/dimension of the centroid vector as representing the "average" review or the average occurances of words for that cluster.

# %%
km_clf.cluster_centers_
# Out:
# array([[0.00134598, 0.00027696, 0.00757935, ..., 0.00081127, 0.0001628 ,
#         0.00046474],
#        [0.00135244, 0.00027081, 0.00895964, ..., 0.00073902, 0.00019527,
#         0.00089532]])

# %% [markdown]
# #### 7. Find the top 20 features for each cluster.
# For topics I am only really interested in the most present words, i.e. features/dimensions with the greatest representation in the centroid.  Print out the top ten words for each centroid.
#
# * Sort each centroid vector to find the top 10 features
# * Go back to my vectorizer object to find out what words each of these features corresponds to.

# %%
cluster_top_features = list()
for i in range(km_clf.n_clusters):
    cluster_top_features.append(np.argsort(km_clf.cluster_centers_[i])[::-1][:40])
for num, centroid in enumerate(cluster_top_features):
    print ('%d: %s' % (num, ", ".join(words[i] for i in centroid)))  #'text'列-评论列的feature_names
# Out:
# 0: food, great, place, good, service, really, time, like, just, restaurant, delicious, nice, amazing, staff, definitely, friendly, best, menu, pizza, ve, came, ordered, come, try, love, got, order, fresh, sushi, don, recommend, experience, price, wait, toronto, pretty, little, table, went, people
# 1: chicken, good, rice, food, fried, sauce, place, ordered, soup, ramen, pork, spicy, like, noodles, really, beef, thai, just, got, curry, came, great, meat, restaurant, delicious, try, definitely, time, dish, order, service, dishes, ve, hot, bit, pretty, bowl, small, taste, come

# %% [markdown]
# It seems that two clusters are both for positive reviews. This is quite strange. Print out the rating and review of a random sample of the reviews assigned to each cluster to get a sense of the cluster.

# %%
for i in range(km_clf.n_clusters):
    sub_cluster = np.arange(0, cluster.shape[0])[cluster == i]  #cluster = km_clf.predict(documents_vec)
    sample = np.random.choice(sub_cluster, 1)
    print("The cluster is %d." % (i+1))
    print("The star is: %s stars." % df['stars'].iloc[sample[0]])
    print("The review is:\n%s.\n" % df['text'].iloc[sample[0]])
# Out:
# The cluster is 1.
# The star is: 5 stars.
# The review is:
# 4 stars for quality of food and 5 stars for experience and atmosphere. This place is a must to everyone who loves south Asian food and culture. Usually a few min wait time, so I suggest walking around and exploring the area a bit.
# Make sure you get the kabobs!.
#
# The cluster is 2.
# The star is: 5 stars.
# The review is:
# Ordered from Ubereats April 22.
# The food came hot and organized in a paper bag. I wouldn't normally bother reviewing an Ubereats order, but their food was that good!
#
# Pros
# Achiote roasted chicken - Amazing flavour, tender and flavourful. The tostones were an unexpected highlight as I don't eat plaintains often.
#
# Pork shoulder - Very unique and tender also came with 2 tostones. The cabbage slaw is surprisingly good.
#
# Buttermilk donuts - Comes with 6 timbits, wow these were amazing, they melted in my mouth.
#
# Cons
# Food portions a bit too big for my liking, I was only able to half of the portion. I guess it's better to get more food than less though.
#
# Protip
# The unique decor and ambience in restaurant is worth going to at least once, I felt like I was in Cuba!
#
# Damage $41 before delivery charge and tip..

# %%
###########################################
clu_num=[]
pop=[]
for j in range(1000):
    for i in range(km_clf.n_clusters):
        sub_cluster = np.arange(0, cluster.shape[0])[cluster == i]
        sample = np.random.choice(sub_cluster, 1)
        clu_num.append(i+1)
        res=df['business_id'].iloc[sample[0]]
        pop.append((df['business_id']==res).value_counts())
pp=[]
for i in pop:
    pp.append(i[1])
from scipy.stats.stats import pearsonr 
print('The correlation coefficient between number of reviews and average rating is %f.' \
      % (pearsonr(clu_num, pp)[0]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-5fb060604c3a> in <module>()
#       4 for j in range(1000):
#       5     for i in range(km_clf.n_clusters):
# ----> 6         sub_cluster = np.arange(0, cluster.shape[0])[cluster == i]
#       7         sample = np.random.choice(sub_cluster, 1)
#       8         clu_num.append(i+1)
#
# NameError: name 'cluster' is not defined

# %% [markdown]
# #### 8. Try different k = 3

# %%
# To be implemented
km_3_clusters = KMeans(verbose = 0, n_clusters = 3)
# km_3_clusters.fit(documents_train_vec)

# %%
km_3_clusters.fit(documents_train_vec)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
cluster_top_features = list()
for i in range(km_3_clusters.n_clusters):
    cluster_top_features.append(np.argsort(km_3_clusters.cluster_centers_[i])[::-1][:40])
for num, centroid in enumerate(cluster_top_features):
    print ('%d: %s' % (num+1, ",".join(words[i] for i in centroid)))
# Out:
# 1: great,food,service,place,good,friendly,amazing,staff,delicious,love,atmosphere,nice,definitely,recommend,really,best,excellent,restaurant,time,fresh,highly,menu,awesome,super,ve,come,price,prices,try,spot,quality,drinks,little,experience,lunch,just,selection,fast,portions,dinner
# 2: food,good,place,like,just,service,time,really,restaurant,order,ordered,pizza,came,got,menu,don,ve,nice,come,try,best,delicious,didn,sushi,table,definitely,wait,went,pretty,fresh,better,people,experience,little,cheese,burger,great,bit,eat,small
# 3: chicken,rice,good,food,soup,fried,noodles,beef,place,pork,ramen,spicy,ordered,sauce,like,really,just,restaurant,got,came,try,thai,dish,delicious,noodle,dishes,time,service,meat,curry,pho,definitely,great,order,broth,ve,hot,pretty,taste,bit

# %% [markdown]
# It seems that three clusters can get the positive, negative and in-between types.

# %%
three_cluster_pred = km_3_clusters.predict(documents_vec)

# %% [markdown]
# Print out the rating and review of a random sample of the reviews assigned to each cluster to get a sense of the cluster.

# %%
print(three_cluster_pred.shape)
print(three_cluster_pred.shape[0])
print(np.arange(0, three_cluster_pred.shape[0]).shape)
# Out:
# (198993,)
# 198993
# (198993,)

# %%
for i in range(km_3_clusters.n_clusters):  #0，1，2
    sub_cluster = np.arange(0, three_cluster_pred.shape[0])[three_cluster_pred == i]  #布尔索引，过滤出聚类分别为0，1，2的在three_cluster_pred中的索引
    sample = np.random.choice(sub_cluster, 1)  #Generates a random sample(第二个参数size) from a given 1-D array
    print(sub_cluster.size,sample.shape)
    print("The cluster is %d." % (i+1))
    print("The star is: %s stars." % df['stars'].iloc[sample[0]])
    print("The review is:\n%s.\n" % df['text'].iloc[sample[0]])
# Out:
# 44659 (1,)
# The cluster is 1.
# The star is: 5 stars.
# The review is:
# This place was an awesome surprise. The ambiance was comfortable and inviting. The food was excellent and the pricing was fair. Our waitress Colleen absolutely made entire experience fantastic..
#
# 114849 (1,)
# The cluster is 2.
# The star is: 1 stars.
# The review is:
# This restaurant is ridiculous. I can't believe how can they be so shameful. I ordered a soon tofu stew for takeout. And guess what?  only 1/3 bowl has thing in it, which is 1/3 height of a white plastic spoon.  The onion isnt cooked at all. And I told them that I will come back in 10 mins to pick it up, when i'm back, the chef was sitting there doing nothing. Didn't start to cook mine until I came back and told them I'm here to pick up what I ordered. ALSO, their side dish is soooo bad. like... the kimchi is not even kimchi, it's just raw cabbage with spicy sauce. Don't even go. What a waste of money..
#
# 39485 (1,)
# The cluster is 3.
# The star is: 4 stars.
# The review is:
# We have been here twice now.  I love Indian food and was introduced to this place several months ago and was really impressed.  It has a clean & simple ambience.  The service is very good, very pleasant, and the manager/owner takes the time to check in and see how you are enjoying your meal.  I did not grow up eating Indian food, I grew up in a very traditional UK home with typically bland and boiled food so I can't speak to authenticity, but the flavours and textures of the beef & chicken kebabs and the chicken tikka was delicious.  We also had the combo sizzling vegetable platter which included Palak, Chana Masala, Aloo Gobi & Tarka Dal.  I enjoyed this platter very much, the only thing I could have wished for was that they separated the four choices better so that I could taste them more individually, they were blended together the way it was dished out.
#
# The vegetable samosas were fantastic, a nice crunchy skin and a really flavourful filling.  The naan was also really good, nice and big.
#
# I had dinner with my husband and as always we ordered too much, we could have used two extra people to help us finish, and we are good eaters!  Our bill only came to $45 (inc. tax).  Really worth a visit..

# %%
df['new_cluster']=[(cluster+1) for cluster in three_cluster_pred]  #df['new_cluster']=list((cluster+1) for cluster in three_cluster_pred)

# %%
df.head(10)
# Out:
#                business_id              name            categories  avg_stars  \
# 2   --1UhMGODdWsrMastO9DZw  The Spicy Amigos  Restaurants, Mexican        4.0
# 3   --1UhMGODdWsrMastO9DZw  The Spicy Amigos  Restaurants, Mexican        4.0
# 5   --1UhMGODdWsrMastO9DZw  The Spicy Amigos  Restaurants, Mexican        4.0
# 6   --1UhMGODdWsrMastO9DZw  The Spicy Amigos  Restaurants, Mexican        4.0
# 7   --1UhMGODdWsrMastO9DZw  The Spicy Amigos  Restaurants, Mexican        4.0
# 12  --1UhMGODdWsrMastO9DZw  The Spicy Amigos  Restaurants, Mexican        4.0
# 13  --1UhMGODdWsrMastO9DZw  The Spicy Amigos  Restaurants, Mexican        4.0
# 14  --1UhMGODdWsrMastO9DZw  The Spicy Amigos  Restaurants, Mexican        4.0
# 16  --1UhMGODdWsrMastO9DZw  The Spicy Amigos  Restaurants, Mexican        4.0
# 17  --1UhMGODdWsrMastO9DZw  The Spicy Amigos  Restaurants, Mexican        4.0
#
#     cool        date  funny               review_id  stars  \
# 2      0  2017-12-12      0  e1HiHHD7CzY5NKZG7hvhTw      5
# 3      0  2017-08-09      0  oKm8UTv-QSC0oCbniqwxjg      4
# 5      1  2017-05-10      0  9CLEOpUCqRkIR02sx-JsMQ      5
# 6      0  2018-01-11      0  hhVr1uH7XaRlbIHI8dYvbA      5
# 7      0  2018-04-22      0  BIecLw546kAlD7kmlk7vXA      2
# 12     2  2017-05-01      1  ZULaTgcgMFJ4SHo_9ZcgxQ      5
# 13     0  2017-12-23      0  EiJoov0ZiIeAB527KizL5Q      5
# 14     0  2017-07-26      0  X4PwY0mMHxqOf2O1pwYdIQ      5
# 16     0  2017-04-03      0  Ueb33Y77jRDQhkjf7nmCUw      5
# 17     0  2017-08-27      0  UfKXTOleA4mtNOOMqzCBTQ      4
#
#                                                  text  useful  \
# 2   Absolutely delicious! And great service as wel...       0
# 3   Tasty, authentic Mexican street food that give...       0
# 672176  2017-10-28      0  hsBriHC-K7kQMKr2EN5IxA      3
# 672177  2017-08-30      0  l-cQlGRKBycL-p8kNFqOPg      4
# 672179  2018-03-11      0  quLyXrPthsXAi9qW5AT4Mw      4
# 672182  2018-01-07      0  _Rf4A9XM9-GgNU6mJoYnzA      5
# 672184  2017-10-08      0  zhpQU7SxUFnLnStFxhtU3w      4
# 672185  2017-06-10      1  kxrb1ofZbLKsmg2Ml0mmlw      3
# 672186  2017-08-26      0  R8DmGCEHPa-gHCcaDj920Q      5
# 672191  2017-05-21      0  VZ3HHh92SK1UwgcoxKTdtg      1
# 672193  2018-04-18      0  t-eE1P1QDiUx5RKx89Mi6g      2
# 672194  2018-03-03      0  G5lVSOMRwLeZq7bVA249EA      5
# 672195  2017-05-14      0  61AoabJ9cl3bNkZh0HIkHA      3
#
#                                                      text  useful  \
# 20      I had the chicken Tinga enchilada in mole sauc...       0
# 21      Downtown west which honestly feels like Downto...       0
# 62      Stopped in on a weekday while in Toronto just ...       4
# 85      Came here on a Sunday afternoon and left feeli...       2
# 91      MochiPopcorn Rating Chart\nAveraged 5 Star Rat...       0
# 97      Surprising for a Chinese restaurant, there is ...       0
# 100     This is pretty much a neighborhood institution...       0
# 102     Come to think of it I haven't been to this Keu...       1
# 107     This is the go-to restaurant for Chinese Canto...       0
# 111     Authentic is what i would call this restaurant...       6
# 117     Hi guys, so today my gf and I went to Flaming ...       0
# 120     For our weekly family dinner this past Sunday,...       0
# 124     Came here to try their sizzling plates during ...       7
# 125     Such a cool hang out spot! You leave here feel...       0
# 127     Compared to Aka Teppan, they have a much large...       0
# 130     My boyfriend and I came here and we left full ...       0
# 131     Location/Service\nRight inside First Markham P...       1
# 132     This place used to be called AKA teppan. Most ...       0
# 133     Rating - 3.0/5.0\n\nThis place opened just rec...       1
# 134     Came here after First markham place, and decid...       0
# 136     My friend and I originally came here because w...       0
# 138     Simple restaurant specializing in sizzling pla...       0
# 139     I used to come here even when it was called Ak...       0
# 141     After Flaming Kitchen took over Aka Tenppan it...       0
# 142     3/5\n\nDid not visit Aka Teppan (previous name...       1
# 143     I had Pepper Lunch 15 years or so ago in Japan...       3
# 144     Tasty food, prompt service! Was very pleased w...       0
# 145     The concept of this place is food on a sizzlin...       5
# 148     Visited a couple times since they rebranded an...       0
# 154     this is similar to mabu which is a couple stor...       0
# ...                                                   ...     ...
# 671734  This a beautiful shop and a good spot to spend...       1
# 671736  I greatly enjoyed Green Grotto. As many fans b...       1
# 671738  I've been to their Warden/Steele location. Thi...       1
# 671756  Honestly one of the best deals around Dundas S...       0
# 671761  Was biking by and stopped in, got the chicken ...       0
# 671763  Let's call this place "a hole in the wall plac...       0
# 671765  Curry Kitchen might not be a fine dining exper...       1
# 671769  - I have tried:\n      + Chicken biriyani ($4....       1
# 671772  Low prices. Food ok. \n\nI had the veggie curr...       0
# 671834  Disgusting food. They only put half of the amo...       0
# 671837  Their photo of Lumprais is NOT lumprais. Lumpr...       1
# 671853  A second trip in 2 weeks. A different waitress...       0
# 671867  Came here for brunch. The dishes are pretty go...       0
# 671952  Overall it is 3.5 stars.\n\nI ordered a Salmon...       3
# 672048  Came here after a friend's birthday dodgeball ...       0
# 672078  I used to love this place but unfortunately th...       0
# 672084  First visit in Calgary and we found this Korea...       0
# 672090  This place is a little gem in a super Asian st...       0
# 672153  Simply the best Jamaican food in town. You can...       0
# 672176  Decent food. Had the bibimbap , fried shrimp a...       0
# 672177  This was a great Korean spot!! We tried the bi...       0
# 672179  The food really was amazing - definitely 5 sta...       0
# 672182  Excellent food. Excellent service. I have been...       2
# 672184  Not a huge selection but all the necessary ite...       0
# 672185  A new Korean place in my hood? Excellent. Now ...       1
# 672186  Had 3 dishes here and all were really good. Th...       1
# 672191  Mislabeling of food. \n\nVisited with my fathe...       2
# 672193  $11 dollars (after tax) for a "Special Pork Sa...       0
# 672194  High underrated spot! The deep fried lotus roo...       0
# 672195  I came here on a Friday night looking for a qu...       0
#
#                        user_id  new_cluster
# 20      Bsy9F-59sl9OT_bvZNl3hA            3
# 21      TzU30D-CjtPP3XumggK0Mg            3
# 62      fn3Wim-2j042IEDe6VhJFQ            3
# 85      6eCgSb66TE1LeiWPPBPnTg            3
# 91      isJEo2IISFonbenri9KQcw            3
# 97      fM9LC2P8jQrQGGsXKccLQw            3
# 100     XbiKsujS_qxU3xsr0xUqmQ            3
# 102     G-6X-llgA_qAxGxocykHzQ            3
# 107     pHUutGZOxIEARm27ODBgvw            3
# 111     CjbfWpCRLbA-L_eS_ztd6Q            3
# 117     9S1vwNxXBWn8NUakv1Vgrw            3
# 120     4RnW-tn6FZsnJF1kkLBOMw            3
# 124     qr06IGEdVEIQmyv-NZe-og            3
# 125     EmfYZX7mfTUB37gSjpcrAg            3
# 127     ZoNEuIMtwJ4BFTG5zs7aqQ            3
# 130     neiVCXD7JJ4wfhaDo3TIOA            3
# 131     4xyYBC5MIe-GfDj6kAdAFw            3
# 132     T1yllPQpkLjmezhW4ufOdQ            3
# 133     WnUDyIE3YWdHcON-i-1MKw            3
# 134     B11X6I4JnpJa9nncfEygRw            3
# 136     b54joGtT-z6kqdmjEGFZcQ            3
# 138     Y9OQzttigHxtqtEbdFLTCA            3
# 139     GrbKHOcLurbZhuXHxEW3RQ            3
# 141     _As_2P_miaPmnUCOgGEf1A            3
# 142     xRBlD49ojkbvoudG9vuqdw            3
# 143     oBjrVmaIylfA8RHOVL_-RQ            3
# 144     KLVH8d5wlM-1wRcEnGM7Rw            3
# 145     Vqp0dpug9Db-kFHO3PkAaQ            3
# 148     upmJkRpBfnbZVKBNGWK1EA            3
# 154     2bSX1ipFgI7AnWHvvjK2Yw            3
# ...                        ...          ...
# 671734  p1F0HCgAggNfneVlFofTkA            3
# 671736  SOdR9t79mZUrUQCRstsUyg            3
# 671738  gI3GyHks_K5LTXqmbBUKgA            3
# 671756  oEXbML5CG19dDtr8HgorYA            3
# 671761  vOAZWoaVySPXn5MmWCIrSw            3
# 671763  hrYOEsw6YkYTf9joi_styw            3
# 671765  Tdp-vTDHrfR2rQk2emDKiA            3
# 671769  -3PTUP443q6hQESLKSu95w            3
# 671772  tU2yeIq93_br0em8Osw5dQ            3
# 671834  SXBx9_ix6aBTmDFRVuNHrw            3
# 671837  hBt-xuX8tTIN30n8UZK1Vw            3
# 671853  c5nn61Y2zRRzoenh9JShPQ            3
# 671867  KBoIRjxSW7OWczv8OS9Bew            3
# 671952  EiP1OFgs-XGcKZux0OKWIA            3
# 672048  AedJ9prHZvr3wBJ_eTsd8g            3
# 672078  PUxKnoH28W1_V3_q1mw4Yw            3
# 672084  _CkACQ3UyqOoeOUsFZKVDA            3
# 672090  nXgklazuzxsn_X8DxOJsEg            3
# 672153  CXB9khfJPkXPf6msMMtspA            3
# 672176  uluaWZj04vfldDEoaIvOhg            3
# 672177  g9uKgUHrMa0rv5-m0muZHA            3
# 672179  WkAiFAJMI7aZPjFqMvsGbA            3
# 672182  FWo1hSUugKWFQwr5IpCANw            3
# 672184  x2rtzRsNrJtnKLwUa9dp1g            3
# 672185  voFxNdzhG-cDrW_9NzFGbw            3
# 672186  xZCVxM7KS49Jj2F_CiiRmA            3
# 672191  DiodkLNDitVCFGK5tAKa8g            3
# 672193  pkRISP8QgKMDPQlr8eNrdA            3
# 672194  U708fyOqNaBU0IQoE6E7WQ            3
# 672195  -PTn0MWCbVFsRhTvxDC12g            3
#
# [39485 rows x 13 columns]

# %%
df.to_csv('2017_restaurant_new_reviews.csv')

# %%
df=pd.read_csv('2017_restaurant_new_reviews.csv')

# %%
df.head()
# Out:
#    Unnamed: 0             business_id              name            categories  \
# 0           2  --1UhMGODdWsrMastO9DZw  The Spicy Amigos  Restaurants, Mexican
# 1           3  --1UhMGODdWsrMastO9DZw  The Spicy Amigos  Restaurants, Mexican
# 2           5  --1UhMGODdWsrMastO9DZw  The Spicy Amigos  Restaurants, Mexican
# 3           6  --1UhMGODdWsrMastO9DZw  The Spicy Amigos  Restaurants, Mexican
# 4           7  --1UhMGODdWsrMastO9DZw  The Spicy Amigos  Restaurants, Mexican
#
#    avg_stars  cool        date  funny               review_id  stars  \
# 0        4.0     0  2017-12-12      0  e1HiHHD7CzY5NKZG7hvhTw      5
# 1        4.0     0  2017-08-09      0  oKm8UTv-QSC0oCbniqwxjg      4
# 2        4.0     1  2017-05-10      0  9CLEOpUCqRkIR02sx-JsMQ      5
# 3        4.0     0  2018-01-11      0  hhVr1uH7XaRlbIHI8dYvbA      5
# 4        4.0     0  2018-04-22      0  BIecLw546kAlD7kmlk7vXA      2
#
#                                                 text  useful  \
# 0  Absolutely delicious! And great service as wel...       0
# 1  Tasty, authentic Mexican street food that give...       0
# 2  A little hole in the wall for some really deli...       0
# 3  Glad these guys moved in on the block! It's qu...       0
# 4  I have been in search of good grilled steak ta...       0
#
#                   user_id  new_cluster
# 0  Sew1Nht6Q0sGTIZeNvRfLw            1
# 1  NoQCmYKyMPs4D01Wa6dZew            1
# 2  atyCaAjUYatIFDOGKy00SA            2
# 3  FYhU1fKQ7n11WQ7gcFYOag            1
# 4  sTVGcezME7gYBhIlYtcfpg            2

# %%
df.count()
# Out:
# Unnamed: 0     198993
# business_id    198993
# name           198993
# categories     198993
# avg_stars      198993
# cool           198993
# date           198993
# funny          198993
# review_id      198993
# stars          198993
# text           198993
# useful         198993
# user_id        198993
# new_cluster    198993
# dtype: int64
